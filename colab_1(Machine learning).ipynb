# %% [markdown]
# <a href="https://colab.research.google.com/github/leehj112/Data-Analyses/blob/master/colab_1(Machine%20learning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('.') # 현재 파일 check
os.listdir('./drive/MyDrive')
# Out:
# ['연새it', 'data', '머신러닝']

# %%
os.listdir('./drive/MyDrive/머신러닝')
# Out:
# ['friend.csv', 'new_friend_index_true.csv', 'new_friend.csv']

# %%
base_src = './drive/MyDrive/머신러닝'

friend_src = base_src + '/friend.csv'

# %%
friend_src
# Out:
# './drive/MyDrive/머신러닝/friend.csv'

# %%
df = pd.read_csv(friend_src, encoding='utf-8')

# %%
# 데이터 읽어보기
df.head()
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager

# %%
new_friend_src = base_src + '/new_friend.csv'
new_friend_src
# Out:
# './drive/MyDrive/머신러닝/new_friend.csv'

# %%
df.to_csv(new_friend_src,index=False, encoding='utf-8')

# %%
os.listdir(base_src)
# Out:
# ['friend.csv', 'new_friend_index_true.csv', 'new_friend.csv']

# %%
new_friend_index_true = pd.read_csv(new_friend_src)

# %%
new_friend_index_true
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
## Series 실습
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
# 데이터프레임(집합) --> 시리즈(단일)
series = df['name']
series
# Out:
# 0     John
# 1    Jenny
# 2     Nate
# 3    Julia
# 4    Brian
# 5    Chris
# Name: name, dtype: object

# %%
# pd.Series 함수를 통해서 만드는 것도 가능
series = pd.Series([1,2,3,4])
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# pd.Series 의 옵션이 무엇이 있는지 확인
# index = 할당값의 지정 이름, 중복 가능['a','b','c','d']
# dtype = 대표적int,float, string, boolearn등
series = pd.Series([1,2,3,4], index=['a','b','c','d'], dtype=float)
series
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
series = pd.Series([10,2,5,4], index=['a','b','c','d'], dtype=float)
series.sort_values(ascending=True)
# Out:
# b     2.0
# d     4.0
# c     5.0
# a    10.0
# dtype: float64

# %%
series = pd.Series([10,2,5,4], index=['a','b','c','d'], dtype=float)
series.sort_values(ascending=False)
# Out:
# a    10.0
# c     5.0
# d     4.0
# b     2.0
# dtype: float64

# %%
# dataframe 실습
df = pd.DataFrame({'a':[2,3],'b':[5,10]}, columns=['b','a'])
df
# Out:
#     b  a
# 0   5  2
# 1  10  3

# %%
new_dict = {'a':2,'b':3,'z':4}

for item,value in new_dict.items():
  print("item :", item)
  print("value:", value)
# Out:
# item : a
# value: 2
# item : b
# value: 3
# item : z
# value: 4

# %%
df = pd.DataFrame([[2,5],[3,10],[10,20]],columns=['a','b'])
df
# Out:
#     a   b
# 0   2   5
# 1   3  10
# 2  10  20

# %%
df = pd.DataFrame([[2,5,100],[3,10,200],[10,20,300]],
                  columns=['a','b','c'],index=['가','나','다'],dtype=float)
df
# Out:
#       a     b      c
# 가   2.0   5.0  100.0
# 나   3.0  10.0  200.0
# 다  10.0  20.0  300.0
