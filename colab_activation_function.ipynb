# %% [markdown]
# <a href="https://colab.research.google.com/github/leehj112/Data-Analyses/blob/master/colab_activation_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

norm = tf.random.normal([1, 5], mean=-1, stddev=10, dtype="half")
print("input : ", norm)

tf.keras.activations.relu(norm).numpy()
# Out:
# input :  tf.Tensor([[ -8.66   -3.834  13.64   -3.236 -23.02 ]], shape=(1, 5), dtype=float16)
# array([[ 0.  ,  0.  , 13.64,  0.  ,  0.  ]], dtype=float16)

# %%
al = tf.keras.activations.relu(norm, alpha=0.5)
max_v = tf.keras.activations.relu(norm, max_value=1)
thres = tf.keras.activations.relu(norm, threshold=norm[0,0])
print("alpha : ", al)
print("\nmax_value : ", max_v)
print("\nthreshold : ", thres)
# Out:
# alpha :  tf.Tensor([[ -4.33   -1.917  13.64   -1.618 -11.51 ]], shape=(1, 5), dtype=float16)
#
# max_value :  tf.Tensor([[0. 0. 1. 0. 0.]], shape=(1, 5), dtype=float16)
#
# threshold :  tf.Tensor([[-0.    -3.834 13.64  -3.236 -0.   ]], shape=(1, 5), dtype=float16)

# %%
from matplotlib import pyplot as plt

in1 = tf.constant([-10, -5.0, -2.0, 0.0, 2.0, 5.0, 10], dtype = tf.float32)
out1 = tf.keras.activations.sigmoid(in1)
print("sigmoid : ", out1)

plt.plot(in1 ,out1)
plt.title("Sigmoid Visualization")
# Out:
# sigmoid :  tf.Tensor(
# [4.5397868e-05 6.6928510e-03 1.1920292e-01 5.0000000e-01 8.8079709e-01
#  9.9330717e-01 9.9995458e-01], shape=(7,), dtype=float32)
# Text(0.5, 1.0, 'Sigmoid Visualization')

# %%
in2 = tf.constant([[0.0, 1.0, 5.0, -2.0, 4.0, 8.0, 3.0]], dtype = tf.float32)
plt.plot(in2[0,:])
plt.title("Input Visualization")
plt.show()

out2 = tf.keras.activations.softmax(in2, axis=-1).numpy()
print("softmax : ", out2)
print("\nsum of softmax : ", out2.sum())

x = [x for x in range(7)]
plt.plot(x, out2[0,x], '-')

plt.title("Softmax Visualization")
plt.show()
# Out:
# softmax :  [[3.1172961e-04 8.4736891e-04 4.6264775e-02 4.2188014e-05 1.7019860e-02
#   9.2925286e-01 6.2612565e-03]]
#
# sum of softmax :  1.0
