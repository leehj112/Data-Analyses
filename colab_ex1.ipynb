# %% [markdown]
# <a href="https://colab.research.google.com/github/leehj112/Data-Analyses/blob/master/colab_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

sample1 = 200 + np.random.randn(10)
print(sample1)

sample2 = 200 + np.random.randn(10)
print(sample2)

print(abs(sample1-sample2))

x = [x for x in range(len(sample2))]
plt.plot(x, sample1, '-')
plt.plot(x, sample2, '-')
plt.fill_between(x, sample1, np.maximum(sample1, sample2),
                 where=(abs(sample1-sample2) > 1), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
# Out:
# [200.72434312 202.12676099 200.57314283 199.89636829 200.34198926
#  200.30670408 200.60128336 200.22872238 200.11919226 199.13742417]
# [199.91869687 200.14294028 198.91561265 201.32052538 199.63879855
#  200.15394142 198.70310757 200.75859766 199.91443874 200.96036509]
# [0.80564625 1.98382071 1.65753018 1.42415709 0.7031907  0.15276266
#  1.89817578 0.52987528 0.20475351 1.82294091]
